# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd
from googlesearch import search

# %%
companies = pd.read_csv("C:/Users/hp/Desktop/DNA/training_data.csv", header = None)
companies = companies[0].tolist()

# %%
def get_soup(url):
    request = urllib.request.Request(url)
    response = urllib.request.urlopen(request)
    soup = BeautifulSoup(response, "html.parser")
    return(soup)

# %%
def get_first_url(query):
    for url in search(query, tld="com.sg", num=1, stop=1, pause=3):
        return url

# %%
def get_address(companies):
    company_details = {}
    for company in companies:
        company_details[company] = {}
        query = company + " pitchbook"
        url=get_first_url(query)
        if url[:38] == "https://pitchbook.com/profiles/company":
            soup = get_soup(url)
            address=[]
            try:
                for line in soup.findAll("li", attrs={"class": "info-item__value"}):
                    add = line.text.strip()
                    address.append(add)
                    addr=", ".join([str(x) for x in address])
                print(company, address)
                company_details[company]["Address"]= addr
            except:
                company_details[company]["Address"]= "NA"
                company_details[company]["Phone"]= "NA"
                continue
        else:
            query = company+" bloomberg snapshot"
            url=get_first_url(query)
            if url[:58] == "https://www.bloomberg.com/research/stocks/private/snapshot":
                soup = get_soup(url)
                address = []
                try:
                    add_line = soup.find("div", attrs={"class": "detailsDataContainerLt"})
                    addr=add_line.find("div", attrs={"itemprop": "address"})
                    for p in addr.findAll("p"):
                        add=p.text.strip()
                        address.append(add)
                    print(company, address)
                    addr=", ".join([str(x) for x in address])
                    print(company, addr)
                    phone = []
                    ph_head = soup.find("div", attrs={"class": "detailsDataContainerRt"})
                    ph = ph_head.find("p", attrs={"itemprop": "telephone"})
                    phone = ph.text.strip()
                    print(phone)
                    company_details[company]["Address"]= addr
                    company_details[company]["Phone"]=phone
                except:
                    company_details[company]["Address"]= "NA"
                    company_details[company]["Phone"]= "NA"
                continue
            
            else:
                print(company, "NA") 
                company_details[company]["Address"]= "NA"
    return company_details

# %%
x=get_address(companies)
x
# Out:
# ABR Holdings Ltd ['ABR Building', '41 Tampines Street 92', 'Singapore, \xa0528881', 'Singapore']
# ABR Holdings Ltd ABR Building, 41 Tampines Street 92, Singapore,  528881, Singapore
# 65 6786 2866
# 2C2P ['51 Tras Street', 'Number 03-00', 'Singapore, 078990', 'Singapore']
# Aetos Security Management ['145 West Coast Road', 'Singapore, \xa0127367', 'Singapore']
# Aetos Security Management 145 West Coast Road, Singapore,  127367, Singapore
# 65 6773 9468
# Near ['35th Floor, UOB Plaza 1', '80 Raffles Place', 'Singapore, 048624', 'Singapore']
# AIBI International ['', ',', 'Singapore']
# AIBI International , ,, Singapore
# Antlabs ['1 Syed Alwi Road', '#03-01 Song Lin Building', 'Singapore, \xa0207628', 'Singapore']
# Antlabs 1 Syed Alwi Road, #03-01 Song Lin Building, Singapore,  207628, Singapore
# 65 6858 6789
# Aspial Corporation ['No. 07-11, Ubi 55 Building', '55 Ubi Avenue 1', 'Singapore, \xa0408935', 'Singapore']
# Aspial Corporation No. 07-11, Ubi 55 Building, 55 Ubi Avenue 1, Singapore,  408935, Singapore
# 1800 382 1111
# Ayam Brand ['27 Rue Du General Foy', 'Paris, \xa075008', 'France']
# Ayam Brand 27 Rue Du General Foy, Paris,  75008, France
# 33 1 30 90 11 73
# Bee Cheng Hiang NA
# Boustead Singapore ['No. 08-01 Edward Boustead Centre', '82 Ubi Avenue 4', 'Singapore, \xa0408832', 'Singapore']
# Boustead Singapore No. 08-01 Edward Boustead Centre, 82 Ubi Avenue 4, Singapore,  408832, Singapore
# 65 6747 0016
# BreadTalk ['30 Tai Seng Street', 'No. 09-01', 'Singapore, 534013', 'Singapore']
# Broadcom Limited ['No. 1 Yishun Avenue 7', 'Floors 1, 2 and 3', 'Singapore, \xa0768923', 'Singapore']
# Broadcom Limited No. 1 Yishun Avenue 7, Floors 1, 2 and 3, Singapore,  768923, Singapore
# 65 6755 7888
# CapitaLand ['168 Robinson Road', 'Number 30-01 Capital Tower', 'Singapore, 068912', 'Singapore']
# Carousell ['71 Ayer Rajah Crescent', 'Suite 02-18', 'Singapore, 139951', 'Singapore']
# Certis CISCO ['20 Jalan Afifi', 'Certis CISCO Centre', 'Singapore, \xa0409179', 'Singapore']
# Certis CISCO 20 Jalan Afifi, Certis CISCO Centre, Singapore,  409179, Singapore
# 65 6747 2888
# Charles & Keith ['6 Tai Seng Link', 'Singapore, 534101', 'Singapore']
# China Aviation Oil ['8 Temasek Boulevard', 'No. 31-02, Suntec Tower Three', 'Singapore, 038988', 'Singapore']
# ComfortDelGro ['205 Braddell Road', 'Singapore, 579701', 'Singapore']
# Creative Technology ['31 International Business Park', 'No. 03-01 Creative Resource', 'Singapore, 609921', 'Singapore']
# DBS Bank ['12 Marina Boulevard', 'Marina Bay Financial Centre', 'Tower Three', 'Singapore, \xa0018982', 'Singapore']
# DBS Bank 12 Marina Boulevard, Marina Bay Financial Centre, Tower Three, Singapore,  018982, Singapore
# dnata Singapore ['50 Airport Boulevard', 'Changi Airport', 'Singapore, \xa0819658', 'Singapore']
# dnata Singapore 50 Airport Boulevard, Changi Airport, Singapore,  819658, Singapore
# 65 6511 0288
# Far East Orchard ['Orchard Parade Hotel', '1 Tanglin Road No.05-01', 'Singapore, 247905', 'Singapore']
# Far East Organization ['14 Scotts Road', '#06-00', 'Far East Plaza', 'Singapore, \xa0228213', 'Singapore']
# Far East Organization 14 Scotts Road, #06-00, Far East Plaza, Singapore,  228213, Singapore
# 65 6235 2411
# FilmTack ['11846 Ventura Boulevard', 'Studio City, CA\xa091604', 'United States']
# FilmTack 11846 Ventura Boulevard, Studio City, CA 91604, United States
# 818-766-2607
# Flextronics ['2 Changi South Lane', 'Singapore, 486123', 'Singapore']
# Fraser and Neave ['438 Alexandra Road', 'Suite 20-00 Alexandra Point', 'Singapore, 119958', 'Singapore']
# Garena ['1 Fusionopolis Place, Suite 17-10', 'Galaxis Building', 'Singapore, 138522', 'Singapore']
# Genting Singapore ['10 Sentosa Gateway', 'Resorts World Sentosa', 'Singapore, 098270', 'Singapore']
# Golden Agri-Resources ['108 Pasir Panjang Road', 'No. 06-00 Golden Agri Plaza', 'Singapore, 118535', 'Singapore']
# Grab ['28 Sin Ming Lane', 'Number 01-143, Midview City', 'Singapore, 573972', 'Singapore']
# Great Eastern Life ['Level 8, HD Tower', 'No. 25 Bis Nguyen Thi Minh Khai, District 1', 'Ho Chi Minh City', 'Vietnam']
# Hyflux ['80 Bendemeer Road', 'Hyflux Innovation Centre', 'Singapore, 339949', 'Singapore']
# Jetstar Asia Airways ['Singapore Changi Airport T1', 'PO Box 323', 'Singapore, \xa0918144', 'Singapore']
# Jetstar Asia Airways Singapore Changi Airport T1, PO Box 323, Singapore,  918144, Singapore
# 65 6499 9702
# Jurong Port ['37 Jurong Port Road', 'Singapore, \xa0619110', 'Singapore']
# Jurong Port 37 Jurong Port Road, Singapore,  619110, Singapore
# 65 6265 0666
# JTC Corporation ['The JTC Summit', '8 Jurong Town Hall Road', 'Singapore, \xa0609434', 'Singapore']
# JTC Corporation The JTC Summit, 8 Jurong Town Hall Road, Singapore,  609434, Singapore
# 65 6560 0056
# Keppel Corporation ['No. 18-01 Keppel Bay Tower', '1 HarbourFront Avenue', 'Singapore, \xa0098632', 'Singapore']
# Keppel Corporation No. 18-01 Keppel Bay Tower, 1 HarbourFront Avenue, Singapore,  098632, Singapore
# 65 6270 6666
# M1 Limited ['10 International Business Park', 'Singapore, \xa0609928', 'Singapore']
# M1 Limited 10 International Business Park, Singapore,  609928, Singapore
# 65 6655 1111
# Mediacorp ['1 Stars Avenue', 'Singapore, 138507', 'Singapore']
# MyRepublic ['33 Ubi Avenue 3', '#04-13', 'Vertex', 'Tower B', 'Singapore, \xa0408868', 'Singapore']
# MyRepublic 33 Ubi Avenue 3, #04-13, Vertex, Tower B, Singapore,  408868, Singapore
# 65 6717 1680
# Neptune Orient Lines ['9 North Buona Vista Drive', 'Suite No. 14-01 The Metropolis', 'Singapore, 138588', 'Singapore']
# NTUC FairPrice ['No. 1 Joo Koon Circle', 'No. 13-01 FairPrice Hub', 'Singapore, \xa0629117', 'Singapore']
# NTUC FairPrice No. 1 Joo Koon Circle, No. 13-01 FairPrice Hub, Singapore,  629117, Singapore
# 65 6888 1888
# OCBC Bank ['65 Chulia Street', 'No 06-00, OCBC Centre', 'Singapore, 049513', 'Singapore']
# Osim International ['65 Ubi Avenue 1', 'OSIM Headquarters', 'Singapore, 408939', 'Singapore']
# PSA International ['PSA Building', '38th Floor', '460 Alexandra Road', 'Singapore, \xa0119963', 'Singapore']
# PSA International PSA Building, 38th Floor, 460 Alexandra Road, Singapore,  119963, Singapore
# 65 6279 4010
# Pacific Century Regional Developments Limited ['50 Raffles Place', 'No 35-01, Singapore Land Tower', 'Singapore, 048623', 'Singapore']
# Popular Holdings ['20 Old Toh Tuck Road', 'Singapore, \xa0597655', 'Singapore']
# Popular Holdings 20 Old Toh Tuck Road, Singapore,  597655, Singapore
# 65 6462 9500
# POSB Bank ['12 Marina Boulevard', 'Marina Bay Financial Centre', 'Tower Three', 'Singapore, \xa0018982', 'Singapore']
# POSB Bank 12 Marina Boulevard, Marina Bay Financial Centre, Tower Three, Singapore,  018982, Singapore
# Quest Global ['7, Temasek Boulevard', '#09-04 Suntec Tower One', 'Singapore, \xa0038987', 'Singapore']
# Quest Global 7, Temasek Boulevard, #09-04 Suntec Tower One, Singapore,  038987, Singapore
# 65 6272 3310
# Renewable Energy Corporation ['', ',', 'China']
# Renewable Energy Corporation , ,, China
# SATS Ltd ['20 Airport Boulevard', 'SATS Inflight Catering Centre 1', 'Singapore, 819659', 'Singapore']
# SBS Transit ['205 Braddell Road', 'Singapore, 579701', 'Singapore']
# Scoot ['1077 Howard Street', 'Suite 105', 'San Francisco, CA 94103', 'United States']
# SearchTrade ['19200 Von Karman Avenue', 'Suite 500', 'Irvine, CA\xa092612', 'United States']
# SearchTrade 19200 Von Karman Avenue, Suite 500, Irvine, CA 92612, United States
# 949-622-5433
# SembCorp Marine ['29 Tanjong Kling Road', 'Singapore, 628054', 'Singapore']
# SIA Engineering Company ['31 Airline Road', 'Singapore, 819831', 'Singapore']
# Singapore Press Holdings ['1000 Toa Payoh North News Centre', 'Singapore, 318994', 'Singapore']
# SMRT Corporation ['6 Ang Mo Kio Street 62', 'Singapore, \xa0569140', 'Singapore']
# SMRT Corporation 6 Ang Mo Kio Street 62, Singapore,  569140, Singapore
# 65 6482 3888
# SGAG ['85 playfair road', 'Suite 06-01, Tong yuan industrial building', 'Singapore, 368000', 'Singapore']
# Sheng Siong ['6 Mandai Link', 'Singapore, 728652', 'Singapore']
# SilkAir ['Level 1 Arrival Hall', 'Passenger Terminal Building 2', 'Changi Airport', 'Singapore, \xa0819829', 'Singapore']
# SilkAir Level 1 Arrival Hall, Passenger Terminal Building 2, Changi Airport, Singapore,  819829, Singapore
# 65 6223 8888
# Singapore Airlines ['25 Airline Road', '07-E Airline House', 'Sinagapore, 819829', 'Singapore']
# Singapore Airlines Cargo ['8E Airline House', '25 Airline Road', 'Singapore, \xa0819829', 'Singapore']
# Singapore Airlines Cargo 8E Airline House, 25 Airline Road, Singapore,  819829, Singapore
# Singapore Exchange ['2 Shenton Way', 'Suite 02-02 SGX Centre 1', 'Singapore, 068804', 'Singapore']
# Singapore Petroleum Company Limited ['One Temasek Avenue #27-00', 'Millenia Tower', 'Singapore, \xa0039192', 'Singapore']
# Singapore Petroleum Company Limited One Temasek Avenue #27-00, Millenia Tower, Singapore,  039192, Singapore
# 65 6276 6006
# Singapore Power ['Singapore', 'Singapore']
# Singapore Post ['10 Eunos Road 8', 'Singapore Post Centre', 'Singapore, \xa0408600', 'Singapore']
# Singapore Post 10 Eunos Road 8, Singapore Post Centre, Singapore,  408600, Singapore
# 65 6845 6775
# Singtel ['31 Exeter Road', 'Singapore, \xa0239732', 'Singapore']
# Singtel 31 Exeter Road, Singapore,  239732, Singapore
# 65 6838 3388
# ST Engineering ['ST Engineering Hub', '1 Ang Mo Kio Electronics Park Road, Suite 07-01', 'Ang Mo Kio, 567710', 'Singapore']
# StarHub ['67 Ubi Avenue 1', 'Suite 05-01 StarHub Green', 'Singapore, 408942', 'Singapore']
# Systems on Silicon Manufacturing ['70 Pasir Ris Industrial Drive 1', 'Singapore, \xa0519527', 'Singapore']
# Systems on Silicon Manufacturing 70 Pasir Ris Industrial Drive 1, Singapore,  519527, Singapore
# 65 6248 7000
# Tangs ['No.399 Chengnan Road', 'Changan Town', 'Haining, 314408', 'China']
# Tee Yih Jia ['1 Senoko Road', 'Tee Yih Jia Building', 'Singapore, \xa0758134', 'Singapore']
# Tee Yih Jia 1 Senoko Road, Tee Yih Jia Building, Singapore,  758134, Singapore
# 65 6880 9888
# Temasek Holdings ['60B Orchard Road', '#06-18 Tower 2', 'The Atrium@ Orchard', 'Singapore, \xa0238891', 'Singapore']
# Temasek Holdings 60B Orchard Road, #06-18 Tower 2, The Atrium@ Orchard, Singapore,  238891, Singapore
# 65 6828 6828
# Thakral Corporation ['20 Upper Circular Road', 'Suite 03-06, The Riverwalk', 'Singapore, 058416', 'Singapore']
# Tiger Airways Holdings ['17 Changi Business Park Central 1', 'No. 04-06/09 Honeywell Building', 'Singapore, Singapore 486073', 'Singapore']
# Twelve Cupcakes ['5 Burn Road', '#04-01', 'Tee Yih Jia Food Building', 'Singapore, \xa0369972', 'Singapore']
# Twelve Cupcakes 5 Burn Road, #04-01, Tee Yih Jia Food Building, Singapore,  369972, Singapore
# 65 6509 1255
# Venture Corporation ['5006 Ang Mo Kio Avenue 5', '05-01/12 TECHplace II', 'Singapore, 569873', 'Singapore']
# Vertex Venture Holdings ['250 North Bridge Road', '011-01 Raffles City Tower', 'Singapore, \xa0179101', 'Singapore']
# Vertex Venture Holdings 250 North Bridge Road, 011-01 Raffles City Tower, Singapore,  179101, Singapore
# 65 6828 8088
# Ya Kun Kaya Toast NA
# Yeo Hiap Seng ['3 Senoko Way', 'Singapore, 758057', 'Singapore']
# Wilmar ['56 Neil Road', 'Singapore, 088830', 'Singapore']
# Trakomatic ['Blk 73 Ayer Rajah Crescent', '#03-01', 'Singapore, 139952', 'Singapore']
# Teamstreamz ['19200 Von Karman Avenue', 'Suite 500', 'Irvine, CA\xa092612', 'United States']
# Teamstreamz 19200 Von Karman Avenue, Suite 500, Irvine, CA 92612, United States
# 949-622-5433
# Knorex ['19200 Von Karman Avenue', 'Suite 500', 'Irvine, CA\xa092612', 'United States']
# Knorex 19200 Von Karman Avenue, Suite 500, Irvine, CA 92612, United States
# 949-622-5433
# DNA Capitals ['Rua Joaquim Floriano', '413, Conj. 112', 'Itaim Bibi, SP\xa02592-0292', 'Brazil']
# DNA Capitals Rua Joaquim Floriano, 413, Conj. 112, Itaim Bibi, SP 2592-0292, Brazil
# 55 11 5682 3241
# Active AI ['10 Anson Road', 'Number 105-17 International Plaza', 'Singapore, 079903', 'Singapore']
# CarPal ['221 Balestier Road', 'Suite 03-07 Rocca Balestier', 'Singapore, 329928', 'Singapore']
# Secretlab ['PO Box 3030', 'West Hobart 7000', 'West Hobart, Tasmania 7000', 'Australia']
# 45RICE ['19200 Von Karman Avenue', 'Suite 500', 'Irvine, CA\xa092612', 'United States']
# 45RICE 19200 Von Karman Avenue, Suite 500, Irvine, CA 92612, United States
# 949-622-5433
# Ice Cube Marketing ['915 Knickerbocker Avenue', 'Brooklyn, NY\xa011207', 'United States']
# Ice Cube Marketing 915 Knickerbocker Avenue, Brooklyn, NY 11207, United States
# 718-456-0033
# Dash Digital ['6230 Wilshire Boulevard', 'Suite 118', 'Los Angeles, CA 90048', 'United States']
# The Living Menu ['14 Floral Street', 'London, \xa0WC2E 9DH', 'United Kingdom']
# The Living Menu 14 Floral Street, London,  WC2E 9DH, United Kingdom
# 44 20 7291 3680
# {'2C2P': {'Address': '51 Tras Street, Number 03-00, Singapore, 078990, Singapore'},
#  '45RICE': {'Address': '19200 Von Karman Avenue, Suite 500, Irvine, CA\xa092612, United States',
#   'Phone': '949-622-5433'},
#  'ABR Holdings Ltd': {'Address': 'ABR Building, 41 Tampines Street 92, Singapore, \xa0528881, Singapore',
#   'Phone': '65 6786 2866'},
#  'AIBI International': {'Address': 'NA', 'Phone': 'NA'},
#  'Active AI': {'Address': '10 Anson Road, Number 105-17 International Plaza, Singapore, 079903, Singapore'},
#  'Aetos Security Management': {'Address': '145 West Coast Road, Singapore, \xa0127367, Singapore',
#   'Phone': '65 6773 9468'},
#  'Antlabs': {'Address': '1 Syed Alwi Road, #03-01 Song Lin Building, Singapore, \xa0207628, Singapore',
#   'Phone': '65 6858 6789'},
#  'Aspial Corporation': {'Address': 'No. 07-11, Ubi 55 Building, 55 Ubi Avenue 1, Singapore, \xa0408935, Singapore',
#   'Phone': '1800 382 1111'},
#  'Ayam Brand': {'Address': '27 Rue Du General Foy, Paris, \xa075008, France',
#   'Phone': '33 1 30 90 11 73'},
#  'Bee Cheng Hiang': {'Address': 'NA'},
#  'Boustead Singapore': {'Address': 'No. 08-01 Edward Boustead Centre, 82 Ubi Avenue 4, Singapore, \xa0408832, Singapore',
#   'Phone': '65 6747 0016'},
#  'BreadTalk': {'Address': '30 Tai Seng Street, No. 09-01, Singapore, 534013, Singapore'},
#  'Broadcom Limited': {'Address': 'No. 1 Yishun Avenue 7, Floors 1, 2 and 3, Singapore, \xa0768923, Singapore',
#   'Phone': '65 6755 7888'},
#  'CapitaLand': {'Address': '168 Robinson Road, Number 30-01 Capital Tower, Singapore, 068912, Singapore'},
#  'CarPal': {'Address': '221 Balestier Road, Suite 03-07 Rocca Balestier, Singapore, 329928, Singapore'},
#  'Carousell': {'Address': '71 Ayer Rajah Crescent, Suite 02-18, Singapore, 139951, Singapore'},
#  'Certis CISCO': {'Address': '20 Jalan Afifi, Certis CISCO Centre, Singapore, \xa0409179, Singapore',
#   'Phone': '65 6747 2888'},
#  'Charles & Keith': {'Address': '6 Tai Seng Link, Singapore, 534101, Singapore'},
#  'China Aviation Oil': {'Address': '8 Temasek Boulevard, No. 31-02, Suntec Tower Three, Singapore, 038988, Singapore'},
#  'ComfortDelGro': {'Address': '205 Braddell Road, Singapore, 579701, Singapore'},
#  'Creative Technology': {'Address': '31 International Business Park, No. 03-01 Creative Resource, Singapore, 609921, Singapore'},
#  'DBS Bank': {'Address': 'NA', 'Phone': 'NA'},
#  'DNA Capitals': {'Address': 'Rua Joaquim Floriano, 413, Conj. 112, Itaim Bibi, SP\xa02592-0292, Brazil',
#   'Phone': '55 11 5682 3241'},
#  'Dash Digital': {'Address': '6230 Wilshire Boulevard, Suite 118, Los Angeles, CA 90048, United States'},
#  'Far East Orchard': {'Address': 'Orchard Parade Hotel, 1 Tanglin Road No.05-01, Singapore, 247905, Singapore'},
#  'Far East Organization': {'Address': '14 Scotts Road, #06-00, Far East Plaza, Singapore, \xa0228213, Singapore',
#   'Phone': '65 6235 2411'},
#  'FilmTack': {'Address': '11846 Ventura Boulevard, Studio City, CA\xa091604, United States',
#   'Phone': '818-766-2607'},
#  'Flextronics': {'Address': '2 Changi South Lane, Singapore, 486123, Singapore'},
#  'Fraser and Neave': {'Address': '438 Alexandra Road, Suite 20-00 Alexandra Point, Singapore, 119958, Singapore'},
#  'Garena': {'Address': '1 Fusionopolis Place, Suite 17-10, Galaxis Building, Singapore, 138522, Singapore'},
#  'Genting Singapore': {'Address': '10 Sentosa Gateway, Resorts World Sentosa, Singapore, 098270, Singapore'},
#  'Golden Agri-Resources': {'Address': '108 Pasir Panjang Road, No. 06-00 Golden Agri Plaza, Singapore, 118535, Singapore'},
#  'Grab': {'Address': '28 Sin Ming Lane, Number 01-143, Midview City, Singapore, 573972, Singapore'},
#  'Great Eastern Life': {'Address': 'Level 8, HD Tower, No. 25 Bis Nguyen Thi Minh Khai, District 1, Ho Chi Minh City, Vietnam'},
#  'Hyflux': {'Address': '80 Bendemeer Road, Hyflux Innovation Centre, Singapore, 339949, Singapore'},
#  'Ice Cube Marketing': {'Address': '915 Knickerbocker Avenue, Brooklyn, NY\xa011207, United States',
#   'Phone': '718-456-0033'},
#  'JTC Corporation': {'Address': 'The JTC Summit, 8 Jurong Town Hall Road, Singapore, \xa0609434, Singapore',
#   'Phone': '65 6560 0056'},
#  'Jetstar Asia Airways': {'Address': 'Singapore Changi Airport T1, PO Box 323, Singapore, \xa0918144, Singapore',
#   'Phone': '65 6499 9702'},
#  'Jurong Port': {'Address': '37 Jurong Port Road, Singapore, \xa0619110, Singapore',
#   'Phone': '65 6265 0666'},
#  'Keppel Corporation': {'Address': 'No. 18-01 Keppel Bay Tower, 1 HarbourFront Avenue, Singapore, \xa0098632, Singapore',
#   'Phone': '65 6270 6666'},
#  'Knorex': {'Address': '19200 Von Karman Avenue, Suite 500, Irvine, CA\xa092612, United States',
#   'Phone': '949-622-5433'},
#  'M1 Limited': {'Address': '10 International Business Park, Singapore, \xa0609928, Singapore',
#   'Phone': '65 6655 1111'},
#  'Mediacorp': {'Address': '1 Stars Avenue, Singapore, 138507, Singapore'},
#  'MyRepublic': {'Address': '33 Ubi Avenue 3, #04-13, Vertex, Tower B, Singapore, \xa0408868, Singapore',
#   'Phone': '65 6717 1680'},
#  'NTUC FairPrice': {'Address': 'No. 1 Joo Koon Circle, No. 13-01 FairPrice Hub, Singapore, \xa0629117, Singapore',
#   'Phone': '65 6888 1888'},
#  'Near': {'Address': '35th Floor, UOB Plaza 1, 80 Raffles Place, Singapore, 048624, Singapore'},
#  'Neptune Orient Lines': {'Address': '9 North Buona Vista Drive, Suite No. 14-01 The Metropolis, Singapore, 138588, Singapore'},
#  'OCBC Bank': {'Address': '65 Chulia Street, No 06-00, OCBC Centre, Singapore, 049513, Singapore'},
#  'Osim International': {'Address': '65 Ubi Avenue 1, OSIM Headquarters, Singapore, 408939, Singapore'},
#  'POSB Bank': {'Address': 'NA', 'Phone': 'NA'},
#  'PSA International': {'Address': 'PSA Building, 38th Floor, 460 Alexandra Road, Singapore, \xa0119963, Singapore',
#   'Phone': '65 6279 4010'},
#  'Pacific Century Regional Developments Limited': {'Address': '50 Raffles Place, No 35-01, Singapore Land Tower, Singapore, 048623, Singapore'},
#  'Popular Holdings': {'Address': '20 Old Toh Tuck Road, Singapore, \xa0597655, Singapore',
#   'Phone': '65 6462 9500'},
#  'Quest Global': {'Address': '7, Temasek Boulevard, #09-04 Suntec Tower One, Singapore, \xa0038987, Singapore',
#   'Phone': '65 6272 3310'},
#  'Renewable Energy Corporation': {'Address': 'NA', 'Phone': 'NA'},
#  'SATS Ltd': {'Address': '20 Airport Boulevard, SATS Inflight Catering Centre 1, Singapore, 819659, Singapore'},
#  'SBS Transit': {'Address': '205 Braddell Road, Singapore, 579701, Singapore'},
#  'SGAG': {'Address': '85 playfair road, Suite 06-01, Tong yuan industrial building, Singapore, 368000, Singapore'},
#  'SIA Engineering Company': {'Address': '31 Airline Road, Singapore, 819831, Singapore'},
#  'SMRT Corporation': {'Address': '6 Ang Mo Kio Street 62, Singapore, \xa0569140, Singapore',
#   'Phone': '65 6482 3888'},
#  'ST Engineering': {'Address': 'ST Engineering Hub, 1 Ang Mo Kio Electronics Park Road, Suite 07-01, Ang Mo Kio, 567710, Singapore'},
#  'Scoot': {'Address': '1077 Howard Street, Suite 105, San Francisco, CA 94103, United States'},
#  'SearchTrade': {'Address': '19200 Von Karman Avenue, Suite 500, Irvine, CA\xa092612, United States',
#   'Phone': '949-622-5433'},
#  'Secretlab': {'Address': 'PO Box 3030, West Hobart 7000, West Hobart, Tasmania 7000, Australia'},
#  'SembCorp Marine': {'Address': '29 Tanjong Kling Road, Singapore, 628054, Singapore'},
#  'Sheng Siong': {'Address': '6 Mandai Link, Singapore, 728652, Singapore'},
#  'SilkAir': {'Address': 'Level 1 Arrival Hall, Passenger Terminal Building 2, Changi Airport, Singapore, \xa0819829, Singapore',
#   'Phone': '65 6223 8888'},
#  'Singapore Airlines': {'Address': '25 Airline Road, 07-E Airline House, Sinagapore, 819829, Singapore'},
#  'Singapore Airlines Cargo': {'Address': 'NA', 'Phone': 'NA'},
#  'Singapore Exchange': {'Address': '2 Shenton Way, Suite 02-02 SGX Centre 1, Singapore, 068804, Singapore'},
#  'Singapore Petroleum Company Limited': {'Address': 'One Temasek Avenue #27-00, Millenia Tower, Singapore, \xa0039192, Singapore',
#   'Phone': '65 6276 6006'},
#  'Singapore Post': {'Address': '10 Eunos Road 8, Singapore Post Centre, Singapore, \xa0408600, Singapore',
#   'Phone': '65 6845 6775'},
#  'Singapore Power': {'Address': 'Singapore, Singapore'},
#  'Singapore Press Holdings': {'Address': '1000 Toa Payoh North News Centre, Singapore, 318994, Singapore'},
#  'Singtel': {'Address': '31 Exeter Road, Singapore, \xa0239732, Singapore',
#   'Phone': '65 6838 3388'},
#  'StarHub': {'Address': '67 Ubi Avenue 1, Suite 05-01 StarHub Green, Singapore, 408942, Singapore'},
#  'Systems on Silicon Manufacturing': {'Address': '70 Pasir Ris Industrial Drive 1, Singapore, \xa0519527, Singapore',
#   'Phone': '65 6248 7000'},
#  'Tangs': {'Address': 'No.399 Chengnan Road, Changan Town, Haining, 314408, China'},
#  'Teamstreamz': {'Address': '19200 Von Karman Avenue, Suite 500, Irvine, CA\xa092612, United States',
#   'Phone': '949-622-5433'},
#  'Tee Yih Jia': {'Address': '1 Senoko Road, Tee Yih Jia Building, Singapore, \xa0758134, Singapore',
#   'Phone': '65 6880 9888'},
#  'Temasek Holdings': {'Address': '60B Orchard Road, #06-18 Tower 2, The Atrium@ Orchard, Singapore, \xa0238891, Singapore',
#   'Phone': '65 6828 6828'},
#  'Thakral Corporation': {'Address': '20 Upper Circular Road, Suite 03-06, The Riverwalk, Singapore, 058416, Singapore'},
#  'The Living Menu': {'Address': '14 Floral Street, London, \xa0WC2E 9DH, United Kingdom',
#   'Phone': '44 20 7291 3680'},
#  'Tiger Airways Holdings': {'Address': '17 Changi Business Park Central 1, No. 04-06/09 Honeywell Building, Singapore, Singapore 486073, Singapore'},
#  'Trakomatic': {'Address': 'Blk 73 Ayer Rajah Crescent, #03-01, Singapore, 139952, Singapore'},
#  'Twelve Cupcakes': {'Address': '5 Burn Road, #04-01, Tee Yih Jia Food Building, Singapore, \xa0369972, Singapore',
#   'Phone': '65 6509 1255'},
#  'Venture Corporation': {'Address': '5006 Ang Mo Kio Avenue 5, 05-01/12 TECHplace II, Singapore, 569873, Singapore'},
#  'Vertex Venture Holdings': {'Address': '250 North Bridge Road, 011-01 Raffles City Tower, Singapore, \xa0179101, Singapore',
#   'Phone': '65 6828 8088'},
#  'Wilmar': {'Address': '56 Neil Road, Singapore, 088830, Singapore'},
#  'Ya Kun Kaya Toast': {'Address': 'NA'},
#  'Yeo Hiap Seng': {'Address': '3 Senoko Way, Singapore, 758057, Singapore'},
#  'dnata Singapore': {'Address': '50 Airport Boulevard, Changi Airport, Singapore, \xa0819658, Singapore',
#   'Phone': '65 6511 0288'}}
